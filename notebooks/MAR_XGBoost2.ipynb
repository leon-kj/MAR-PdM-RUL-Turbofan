# %% [markdown]
# # Vorhersage eines Triebwerksausfalls aufgrund von Sensormesswerten mit XGBoost

# %%
import h5py
import numpy as np
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = '../data/N-CMAPSS_DS03-012.h5'

# %%
# Load data
with h5py.File(filename, 'r') as hdf:
        # Development set
        W_train = np.array(hdf.get('W_dev'))           # W
        X_s_train = np.array(hdf.get('X_s_dev'))       # Sensors
        Y_train = np.array(hdf.get('Y_dev'))           # RUL  
        A_train = np.array(hdf.get('A_dev'))           # Auxiliary

        # Test set
        W_test = np.array(hdf.get('W_test'))           # W
        X_s_test = np.array(hdf.get('X_s_test'))       # Sensors
        Y_test = np.array(hdf.get('Y_test'))           # RUL  
        A_test = np.array(hdf.get('A_test'))           # Auxiliary
        
        # Varnams
        W_var = np.array(hdf.get('W_var'))
        X_s_var = np.array(hdf.get('X_s_var'))
        A_var = np.array(hdf.get('A_var'))
        
        # from np.array to list dtype U4/U5
        W_var = list(np.array(W_var, dtype='U20'))
        X_s_var = list(np.array(X_s_var, dtype='U20'))
        A_var = list(np.array(A_var, dtype='U20'))

# %% [markdown]
# Der folgende Codeblock extrahiert drei Treibwerke aus dem Trainset und aus dem Testset, dies ist für das Training des ML-Modells nötig.

# %%
# Masks
mask_dev_units = np.isin(A_train[:,0].astype(int), [4, 5])
mask_test_units = np.isin(A_test[:,0].astype(int), [11])

# Extract chosen units
X_s_dev = np.concatenate([X_s_train[mask_dev_units], X_s_test[mask_test_units]], axis=0)
W_dev = np.concatenate([W_train[mask_dev_units], W_test[mask_test_units]], axis=0)
Y_dev = np.concatenate([Y_train[mask_dev_units], Y_test[mask_test_units]], axis=0).ravel()
A_dev = np.concatenate([A_train[mask_dev_units], A_test[mask_test_units]], axis=0)

# Remove chosen units from train and test sets
X_s_train = X_s_train[~mask_dev_units]
W_train = W_train[~mask_dev_units]
Y_train = Y_train[~mask_dev_units]
A_train = A_train[~mask_dev_units]

X_s_test = X_s_test[~mask_test_units]
W_test = W_test[~mask_test_units]
Y_test = Y_test[~mask_test_units]
A_test = A_test[~mask_test_units]

# %%
df_A = DataFrame(data=A_train, columns=A_var)
df_A_dev = DataFrame(data=A_dev, columns=A_var)
df_A_test = DataFrame(data=A_test, columns=A_var)
df_A.describe()
# Out:
#                unit         cycle            Fc            hs
# count  4.631047e+06  4.631047e+06  4.631047e+06  4.631047e+06
# mean   5.577160e+00  3.601043e+01  2.291261e+00  3.218762e-01
# std    2.579950e+00  2.112944e+01  7.049348e-01  4.671959e-01
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    3.000000e+00  1.800000e+01  2.000000e+00  0.000000e+00
# 50%    6.000000e+00  3.600000e+01  2.000000e+00  0.000000e+00
# 75%    8.000000e+00  5.400000e+01  3.000000e+00  1.000000e+00
# max    9.000000e+00  8.400000e+01  3.000000e+00  1.000000e+00

# %% [markdown]
# ### Unit Ids
# Mit diesem Codeabschnitt wird geschaut wie viele Triebwerke im Devset und im Testset sind.

# %%
print(np.unique(df_A["unit"]))
print(np.unique(df_A_dev["unit"]))
print(np.unique(df_A_test["unit"]))
# Out:
# [1. 2. 3. 6. 7. 8. 9.]
# [ 4.  5. 11.]
# [10. 12. 13. 14. 15.]

# %% [markdown]
# ### Verfügbare Triebwerke pro Flugklasse

# %%
labelsize = 17
plt.figure(figsize=(10,4))
# trainset 
plt.plot(df_A.unit, df_A.Fc, 'o', color='Blue')
plt.tick_params(axis='x', labelsize=labelsize )
plt.tick_params(axis='y', labelsize=labelsize )
plt.xlabel('Unit # [-]', fontsize=labelsize)
plt.ylabel('Flight Class # [-]', fontsize=labelsize )

# devset
plt.plot(df_A_dev.unit, df_A_dev.Fc, 'o', color='Green')
plt.tick_params(axis='x', labelsize=labelsize )
plt.tick_params(axis='y', labelsize=labelsize )

# testset
plt.plot(df_A_test.unit, df_A_test.Fc, 'o', color='Orange')
plt.tick_params(axis='x', labelsize=labelsize )
plt.tick_params(axis='y', labelsize=labelsize )

# %% [markdown]
# ## Analyse der Sensordaten

# %%
df = DataFrame(X_s_train, columns=X_s_var)

# Add auxiliary info
df["unit"]  = A_train[:, 0].astype(int)
df["cycle"] = A_train[:, 1].astype(int)
df["Fc"]    = A_train[:, 2].astype(int)
df["hs"]    = A_train[:, 3].astype(int)

# Add target (RUL)
df["RUL"] = Y_train

unit_to_plot = 2          # pick a unit
sensor = "P24"       # pick a sensor column name

df_unit = df[df["unit"] == unit_to_plot]

fig, ax1 = plt.subplots(figsize=(10,4))
ax1.plot(df_unit["cycle"], df_unit[sensor], label=sensor)
ax1.set_xlabel("Cycle")
ax1.set_ylabel(sensor)

# add trendline
z = np.polyfit(df_unit["cycle"], df_unit[sensor], 1)
p = np.poly1d(z)
ax1.plot(df_unit["cycle"], p(df_unit["cycle"]), color="green", linestyle=":", label="Trendline")

ax2 = ax1.twinx()
ax2.plot(df_unit["cycle"], df_unit["RUL"], linestyle="--", color="red", label="RUL")
ax2.set_ylabel("RUL")


# Merge legends
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="best")

plt.title(f"Unit {unit_to_plot} - {sensor} vs RUL")
plt.show()

# %% [markdown]
# Die Folgende Grafik veranschaulicht, wieso es es einen zusammenhang zwischen Sensoren und der Höhe und weiteren Werten gibt.

# %%
df_X = DataFrame(X_s_train, columns=X_s_var)
df_rpm = DataFrame(W_train, columns=W_var)
df_rpm["Nf"] = df_X["Nf"].astype(float)
df_rpm["unit"] = A_train[:, 0].astype(int)
df_rpm["cycle"] = A_train[:, 1].astype(int)

unit_to_plot = 2
cycle_to_plot = 30

df_unit_cycle = df_rpm[(df_rpm["unit"] == unit_to_plot) & (df_rpm["cycle"] == cycle_to_plot)]

fig, ax1 = plt.subplots(figsize=(10,4))
ax1.plot(df_unit_cycle["TRA"], label="Throttle-Resolver Angle [%]")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Throttle-Resolver Angle [%]")

ax2 = ax1.twinx()
ax2.plot(df_unit_cycle["Nf"], label="Physical fan speed [rpm]", color="Orange")
ax2.set_ylabel("Physical fan speed [rpm]")

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="best")

plt.title(f"Unit {unit_to_plot} - Cycle {cycle_to_plot} - Physical fan speed vs Throttle-Resolver Angle")
plt.show()

# %%
df_Temperature = DataFrame(W_train, columns=W_var)
df_Temperature["unit"] = A_train[:, 0].astype(int)
df_Temperature["cycle"] = A_train[:, 1].astype(int)

unit_to_plot = 2
cycle_to_plot = 30

df_unit_cycle = df_Temperature[(df_Temperature["unit"] == unit_to_plot) & (df_Temperature["cycle"] == cycle_to_plot)]

fig, ax1 = plt.subplots(figsize=(10,4))
ax1.plot(df_unit_cycle["T2"], label="Total temperature at fan inlet [°R]")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Total temperature at fan inlet [°R]")

ax2 = ax1.twinx()
ax2.plot(df_unit_cycle["alt"], label="Altitude [ft]", color="Orange")
ax2.set_ylabel("Altitude [ft]")

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="upper right")

plt.title(f"Unit {unit_to_plot} - Cycle {cycle_to_plot} - Sensor T2 vs Altitude")
plt.show()

# %%
unit_to_plot = 2    
cycle_to_plot = 5     
sensor = "sensor_5"       

df = DataFrame(X_s_train, columns=[f"sensor_{i}" for i in range(X_s_train.shape[1])])
df["unit"]  = A_train[:, 0].astype(int)
df["cycle"] = A_train[:, 1].astype(int)

df_unit_cycle = df[(df["unit"] == unit_to_plot) & (df["cycle"] == cycle_to_plot)]
df_unit_cycle.describe()

plt.plot(df_unit_cycle[sensor])
plt.xlabel("Time")
plt.ylabel(sensor)
plt.title(f"Unit {unit_to_plot} - Cycle {cycle_to_plot} - {sensor}")
# Out:
# Text(0.5, 1.0, 'Unit 2 - Cycle 5 - sensor_5')

# %% [markdown]
# ## Datenaufbereitung

# %%
# Train
fc = A_train[:, 0].reshape(-1, 1)
X_train = np.concatenate((X_s_train, fc, W_train), axis=1)
Y_train = Y_train.ravel()

# Dev
fc_dev = A_dev[:, 0].reshape(-1, 1)
X_dev = np.concatenate((X_s_dev, fc_dev, W_dev), axis=1)
Y_dev = Y_dev.ravel()

# Test
fc_test = A_test[:, 0].reshape(-1, 1)
X_test = X_s_test
X_test = np.concatenate((X_test, fc_test, W_test), axis=1)
Y_test = Y_test.ravel()

# %% [markdown]
# ## XGBoost

# %%
# Import
import xgboost as xgb
from sklearn.metrics import root_mean_squared_error

# %%
feature_names = (X_s_var + ["fc"] + W_var)
dtrain = xgb.DMatrix(X_train, label=Y_train, feature_names=feature_names)
ddev = xgb.DMatrix(X_dev, label=Y_dev, feature_names=feature_names)
dtest = xgb.DMatrix(X_test, label=Y_test, feature_names=feature_names)

# %% [markdown]
# ### Model Training

# %%
# Training parameters
params = {
    "objective": "reg:squarederror",   # regression
    "max_depth": 5,                    # tree depth
    "eta": 0.05,                       # learning rate
    "subsample": 0.8,                  # row sampling
    "colsample_bytree": 0.8,           # feature
    "gamma": 0.1,                      # require improvement to split 
    "tree_method": "hist",             # use GPU for training
    "device": "cuda",                  # use GPU
    "seed": 42
}

# Train model
num_round = 600
evallist = [(dtrain, "train"), (ddev, "eval")]

bst = xgb.train(
    params, 
    dtrain, 
    num_round, 
    evals=evallist, 
    early_stopping_rounds=50,  # stop if no improvement
    verbose_eval=10            # print progress every 10 rounds
)

bst.save_model("../models/xgb_rul2.json")
# Out:
# [0]	train-rmse:20.94458	eval-rmse:21.02209
# [10]	train-rmse:19.80419	eval-rmse:20.63566
# [20]	train-rmse:19.03988	eval-rmse:21.09414
# [30]	train-rmse:18.45318	eval-rmse:21.36846
# [40]	train-rmse:17.77146	eval-rmse:21.14523
# [50]	train-rmse:17.19588	eval-rmse:20.81401
# [60]	train-rmse:16.63688	eval-rmse:20.44266
# [70]	train-rmse:16.22594	eval-rmse:20.21374
# [80]	train-rmse:15.75872	eval-rmse:19.87019
# [90]	train-rmse:15.39504	eval-rmse:19.62858
# [100]	train-rmse:15.03223	eval-rmse:19.39807
# [110]	train-rmse:14.69494	eval-rmse:19.37495
# [120]	train-rmse:14.38746	eval-rmse:19.17343
# [130]	train-rmse:14.06366	eval-rmse:19.13132
# [140]	train-rmse:13.78976	eval-rmse:18.94556
# [150]	train-rmse:13.51525	eval-rmse:18.78200
# [160]	train-rmse:13.23748	eval-rmse:18.60389
# [170]	train-rmse:13.02375	eval-rmse:18.48605
# [180]	train-rmse:12.81833	eval-rmse:18.36079
# [190]	train-rmse:12.61058	eval-rmse:18.23215
# [200]	train-rmse:12.39831	eval-rmse:18.11244
# [210]	train-rmse:12.21750	eval-rmse:18.00998
# [220]	train-rmse:12.04453	eval-rmse:18.07374
# [230]	train-rmse:11.88875	eval-rmse:17.99637
# [240]	train-rmse:11.70805	eval-rmse:17.88910
# [250]	train-rmse:11.56173	eval-rmse:17.81317
# [260]	train-rmse:11.42944	eval-rmse:17.76159
# [270]	train-rmse:11.29656	eval-rmse:17.68766
# [280]	train-rmse:11.17890	eval-rmse:17.63384
# [290]	train-rmse:11.06007	eval-rmse:17.58861
# [300]	train-rmse:10.93589	eval-rmse:17.52784
# [310]	train-rmse:10.82863	eval-rmse:17.48513
# [320]	train-rmse:10.71469	eval-rmse:17.43468
# [330]	train-rmse:10.61841	eval-rmse:17.40584
# [340]	train-rmse:10.52720	eval-rmse:17.37043
# [350]	train-rmse:10.44337	eval-rmse:17.35370
# [360]	train-rmse:10.35782	eval-rmse:17.32643
# [370]	train-rmse:10.27796	eval-rmse:17.30266
# [380]	train-rmse:10.19919	eval-rmse:17.26384
# [390]	train-rmse:10.12362	eval-rmse:17.23364
# [400]	train-rmse:10.05662	eval-rmse:17.22261
# [410]	train-rmse:9.98767	eval-rmse:17.19894
# [420]	train-rmse:9.93030	eval-rmse:17.21535
# [430]	train-rmse:9.87088	eval-rmse:17.21752
# [440]	train-rmse:9.80417	eval-rmse:17.19405
# [450]	train-rmse:9.73627	eval-rmse:17.16329
# [460]	train-rmse:9.67473	eval-rmse:17.14022
# [470]	train-rmse:9.62268	eval-rmse:17.12109
# [480]	train-rmse:9.56679	eval-rmse:17.09980
# [490]	train-rmse:9.51770	eval-rmse:17.14693
# [500]	train-rmse:9.46922	eval-rmse:17.14085
# [510]	train-rmse:9.42023	eval-rmse:17.12692
# [520]	train-rmse:9.37051	eval-rmse:17.10740
# [530]	train-rmse:9.33670	eval-rmse:17.10973
# [533]	train-rmse:9.32134	eval-rmse:17.09984

# %% [markdown]
# ### Vorhersage

# %%
# Load the model
model = xgb.Booster()
model.load_model("../models/xgb_rul2.json")

# Predict
Y_pred = model.predict(dtest)

# %% [markdown]
# ### Evaluation

# %%
# Evaluation
rmse = root_mean_squared_error(Y_test, Y_pred)
print(f"Test RMSE: {rmse:.2f}")
# Out:
# Test RMSE: 15.44

# %%
# Feature importances
fig, ax = plt.subplots(figsize=(10, 4))
xgb.plot_importance(model, importance_type="gain", height=0.5, ax=ax)
ax.set_ylabel("Feature")
ax.set_xlabel("Importance")
ax.set_title("XGBoost 2 Feature Importances")
plt.show()

# %%
unit_ids_test = A_test[:, 0]
unit = 12
indices = np.where(unit_ids_test == unit)[0]

plt.figure(figsize=(10, 4))
plt.plot(Y_pred[indices], label="Predicted RUL", color='tab:orange')
plt.plot(Y_test[indices], label="True RUL", color='tab:blue')
plt.title(f"Engine {unit} - XGBoost 2 - True vs Predicted RUL")
plt.xlabel("Time step [s]")
plt.ylabel("RUL")
plt.legend()
plt.grid(True)
plt.show()
